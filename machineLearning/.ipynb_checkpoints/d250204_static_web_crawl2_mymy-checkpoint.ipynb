# %% [markdown]
# # 할리스 커피 매장 정보 크롤링

# %% [markdown]
# ```
# # BeautifulSoup 객체를 생성해서 파싱
# # 1. 1 ~ 49 페이지까지 반복해서 url 설정
# # 2. url 요청하여 응답받은 웹페이지 저장
# # 3. BeautifulSoup 객체 생성
# # 4. tr 태그 하위의 td 태그 중에서 필요한 항목만 추출하여 result 리스트에 추가 저장
# ```

# %%
import urllib.request
import pandas as pd
from bs4 import BeautifulSoup, Comment

# %%
result = []

def my_parser():
    url = 'https://www.hollys.co.kr/store/korea/korStore2.do?pageNo='
    page_url = [url + str(i) for i in range(1, 50)]

    for i in range(0, 49):
        print(page_url[i] + " 페이지 시작 ===")
        request = urllib.request.Request(page_url[i])
        response = urllib.request.urlopen(request)
        
        html = response.read().decode('utf-8')
        soup = BeautifulSoup(html, "html.parser")
        
        tbl = soup.select('table.tb_store tbody tr')
        
        
        for tr in tbl:
            txt_list = []
            for td in tr.find_all("td"):
                txt = ''
                if td.find_all("img"):
                    alt = [img["alt"] for img in td.find_all("img") if img.has_attr("alt")]
                    txt = ", ".join(alt)
                else:
                    txt = td.get_text(strip=True)
                    if txt == '': txt = 'NULL'
                txt_list.append(txt)
            result.append(txt_list)
                
        print(page_url[i] + " 페이지 완료 ===")
        
        #if i == 1: break


my_parser()
# Out:
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=1 페이지 시작 ===
# 1페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=2 페이지 시작 ===
# 2페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=3 페이지 시작 ===
# 3페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=4 페이지 시작 ===
# 4페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=5 페이지 시작 ===
# 5페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=6 페이지 시작 ===
# 6페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=7 페이지 시작 ===
# 7페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=8 페이지 시작 ===
# 8페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=9 페이지 시작 ===
# 9페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=10 페이지 시작 ===
# 10페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=11 페이지 시작 ===
# 11페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=12 페이지 시작 ===
# 12페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=13 페이지 시작 ===
# 13페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=14 페이지 시작 ===
# 14페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=15 페이지 시작 ===
# 15페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=16 페이지 시작 ===
# 16페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=17 페이지 시작 ===
# 17페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=18 페이지 시작 ===
# 18페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=19 페이지 시작 ===
# 19페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=20 페이지 시작 ===
# 20페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=21 페이지 시작 ===
# 21페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=22 페이지 시작 ===
# 22페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=23 페이지 시작 ===
# 23페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=24 페이지 시작 ===
# 24페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=25 페이지 시작 ===
# 25페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=26 페이지 시작 ===
# 26페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=27 페이지 시작 ===
# 27페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=28 페이지 시작 ===
# 28페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=29 페이지 시작 ===
# 29페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=30 페이지 시작 ===
# 30페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=31 페이지 시작 ===
# 31페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=32 페이지 시작 ===
# 32페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=33 페이지 시작 ===
# 33페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=34 페이지 시작 ===
# 34페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=35 페이지 시작 ===
# 35페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=36 페이지 시작 ===
# 36페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=37 페이지 시작 ===
# 37페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=38 페이지 시작 ===
# 38페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=39 페이지 시작 ===
# 39페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=40 페이지 시작 ===
# 40페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=41 페이지 시작 ===
# 41페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=42 페이지 시작 ===
# 42페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=43 페이지 시작 ===
# 43페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=44 페이지 시작 ===
# 44페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=45 페이지 시작 ===
# 45페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=46 페이지 시작 ===
# 46페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=47 페이지 시작 ===
# 47페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=48 페이지 시작 ===
# 48페이지 완료 ===
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=49 페이지 시작 ===
# 49페이지 완료 ===

# %%
result
# Out:
# [['전북 전주시 덕진구',
#   '전주백제대로점2',
#   '영업중',
#   '전라북도 전주시 덕진구 백제대로 592 (금암동) 1층',
#   '주차',
#   '063-271-5056'],
#  ['경기 성남시 분당구',
#   '분당미금점',
#   '영업중',
#   '경기도 성남시 분당구 미금일로90번길 24 (구미동) B1F ~ 1F',
#   '주차',
#   '031-713-7739'],
#  ['부산 기장군',
#   '부산일광신도시점',
#   '영업중',
#   '부산광역시 기장군 일광읍 해빛6로 43-20 .',
#   '주차',
#   '070-4790-2715'],
#  ['서울 중구',
#   '메리츠봉래타워점',
#   '영업중',
#   '서울시 중구 칠패로 28 메리츠강북타워 1층',
#   'NULL',
#   '02-753-8835'],
#  ['경기 성남시 중원구',
#   '성남모란역점',
#   '영업중',
#   '경기도 성남시 중원구 성남대로1148번길 8 (성남동) 1층, 성남동3453',
#   'NULL',
#   '031-758-5953'],
#  ['경기 고양시 덕양구',
#   '고양시청DI점',
#   '영업중',
#   '경기도 고양시 덕양구 호국로 730 2F',
#   '테라스, 주차',
#   '031-812-0105'],
#  ['강원 원주시',
#   '(춘)치악휴게소점',
#   '영업중',
#   '강원도 원주시 신림면 다리실2길 32 .',
#   '테라스, 주차',
#   '033-762-8129'],
#  ['인천 남동구',
#   '간석오거리점',
#   '영업중',
#   '인천광역시 남동구 남동대로 931 (간석동) 씨앤케이 웨딩홀',
#   '주차',
#   '032-425-0915'],
#  ['대구 수성구',
#   '대구범어천로점',
#   '영업중',
#   '대구광역시 수성구 범어천로 200 (범어동, 범어월드메르디앙웨스턴카운티) 102호, 201호',
#   '주차',
#   '053-759-5779'],
#  ['서울 강동구',
#   '길동포유르센티점',
#   '영업중',
#   '서울특별시 강동구 진황도로 104 (길동) 1층 (101~102호)',
#   'NULL',
#   '02-487-9997'],
#  ['서울 강동구',
#   '고덕비즈밸리점',
#   '영업중',
#   '서울특별시 강동구 고덕비즈밸리로 38 (고덕동) KS타워 101호~102호',
#   '테라스, 주차',
#   '.'],
#  ['경남 창원시 의창구',
#   '창원팔용점',
#   '영업중',
#   '경상남도 창원시 의창구 창원대로18번길 6-8 (팔용동) 할리스 창원팔용점',
#   '테라스, 흡연시설, 주차',
#   '.'],
#  ['서울 강남구',
#   '파르나스몰점',
#   '영업중',
#   '서울특별시 강남구 테헤란로 521 (삼성동, 파르나스타워) 파르나스몰 내 B1층 F-3a호',
#   '주차',
#   '02-3453-1024'],
#  ['서울 노원구', '석계역점', '영업중', '서울시 노원구 화랑로 325 1층', '주차', '02-942-1345'],
#  ['강원 동해시',
#   '동해묵호점',
#   '영업중',
#   '강원특별자치도 동해시 해안로 368 (평릉동, 할리스커피) 1~3층',
#   '테라스, 주차',
#   '033-534-8902'],
#  ['충남 홍성군',
#   '충남도청점',
#   '영업중',
#   '충청남도 홍성군 홍북읍 청사로174번길 25 (성원타워) .',
#   '주차',
#   '041-631-4725'],
#  ['서울 동작구',
#   '신대방삼거리역점',
#   '영업중',
#   '서울특별시 동작구 상도로 60 (대방동) 1층~2층',
#   '주차',
#   '02-823-2377'],
#  ['세종',
#   '세종국책연구단지점',
#   '영업중',
#   '세종특별자치시 시청대로 370 (반곡동, 나라키움세종국책연구단지) .',
#   '주차',
#   '044-865-4684'],
#  ['부산 사하구',
#   '동아대 인문대점',
#   '영업중',
#   '부산광역시 사하구 낙동대로550번길 37 (하단동, 동아대학교) S01 인문대 카페',
#   'NULL',
#   '051-200-6165'],
#  ['경남 진주시',
#   '경상대 느티마루점',
#   '영업중',
#   '경상남도 진주시 진주대로 501 (가좌동, 경상국립대학교가좌캠퍼스) .',
#   'NULL',
#   '.']]

# %%
df = pd.DataFrame(result)
thead_list = [th.get_text(strip=True).replace(" ", "") for th in soup.select('table.tb_store thead tr th')]
df.columns = thead_list
df.index = range(1, len(df)+1)
# df = df.reset_index(drop=True)  # 기존 인덱스 삭제
# df.index += 1  # 1부터 시작하는 인덱스 설정
#df.head(30)
df = df.drop(['현황'], axis=1)

# %%
df.to_csv('data/hollys.csv', encoding='cp949')
