# %%
import os
import sys
import urllib.request

# %%
# # 네이버 검색 API 예제 - 블로그 검색
# import os
# import sys
# import urllib.request
# client_id = "YOUR_CLIENT_ID"
# client_secret = "YOUR_CLIENT_SECRET"
# encText = urllib.parse.quote("검색할 단어")
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)
# response = urllib.request.urlopen(request)
# rescode = response.getcode()
# if(rescode==200):
#     response_body = response.read()
#     print(response_body.decode('utf-8'))
# else:
#     print("Error Code:" + rescode)

# %%
import os
import sys
import urllib.request
import datetime
import time
import json

client_id = "zKMOXjDPaWWWjbrJYKkN"
client_secret = "l73i051J40"

def getRequestUrl(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    try:
        response = urllib.request.urlopen(request)
        if response.getcode() == 200:
            print("[%s] url request success" % datetime.datetime.now())
            return response.read().decode("utf-8")
    except Exception as e:
        print(e)
        print("[%s] error for url : %s" % (datetime.datetime.now(), url))
        return None

def getNaverSearch(node, srcText, start, display):
    base = "https://openapi.naver.com/v1/search/"
    node = "%s.json" % node
    params = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), start, display)
    url = base + node + params
    responseDecode = getRequestUrl(url)

    if responseDecode == None:
        return None
    else: 
        return json.loads(responseDecode)

def getPostDate(post, jsonResult, cnt):
    title = post['title']
    description = post['description']
    org_link = post['originallink']
    link = post['link']
    pDate = datetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S +0900')
    pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')
    jsonResult.append({'cnt':cnt, 'description': description, 'org_link': org_link, 'link': org_link, 'pDate': pDate})
    
def main():
    node = 'news'
    srcText = input("검색어를 입력: ")
    cnt = 0
    jsonResult = []
    jsonResponse = getNaverSearch(node, srcText, 1, 100)
    total = jsonResponse['total']

    while jsonResponse != None and jsonResponse['display'] != 0:
        for post in jsonResponse['items']:
            cnt += 1
            getPostDate(post, jsonResult, cnt)

        start = jsonResponse['start'] + jsonResponse['display']
        jsonResponse = getNaverSearch(node, srcText, start, 100)

    print('전체 검색 : %d ' % total)

    with open('data/%s_naver_%s.json' % (srcText, node), 'w', encoding='utf=8') as outfile:
        jsonFile = json.dumps(jsonResult, indent=4, sort_keys=True, ensure_ascii=False)
        outfile.write(jsonFile)
    print("가져온 데이터:", cnt)
    print(jsonFile, "saved ")



if __name__ == "__main__":
    main()
# Out:
# 검색어를 입력:  트럼프
# [2025-02-03 13:17:31.642816] url request success
# [2025-02-03 13:17:31.977960] url request success
# [2025-02-03 13:17:32.140325] url request success
# [2025-02-03 13:17:32.334382] url request success
# [2025-02-03 13:17:32.554728] url request success
# [2025-02-03 13:17:32.831765] url request success
# [2025-02-03 13:17:33.046775] url request success
# [2025-02-03 13:17:33.264241] url request success
# [2025-02-03 13:17:33.486809] url request success
# [2025-02-03 13:17:33.711139] url request success
# HTTP Error 400: Bad Request
# [2025-02-03 13:17:33.784471] error for url : https://openapi.naver.com/v1/search/news.json?query=%ED%8A%B8%EB%9F%BC%ED%94%84&start=1001&display=100
# 전체 검색 : 1670699
# 가져온 데이터: 1000
# [
#     {
#         "cnt": 1,
#         "description": "이번 세미나는 새해 및 <b>트럼프</b> 2기를 맞이해 자산관리의 방향을 잡자는 취지로 진행된다. 첫번째 회차인 2월 5일에는 미래에셋증권 분당WM 지점장인 조혁진 이사가 '지점장에게 직접 들어보는 2025년 자산관리 전략'을... ",
# ...

# %%
# import os
# import sys
# import urllib.request
# import datetime
# import time
# import json 

# class naverAPI:
#     def __init__(self, node):
        
#         self.node = node
#         self.search_txt = urllib.parse.quote(input('검색어 입력 : '))
#         self.url = f"https://openapi.naver.com/v1/search/{self.node}.json?query=" + self.search_txt 
#         self.client_id = "zKMOXjDPaWWWjbrJYKkN"
#         self.client_secret = "l73i051J40"
#         self.start = 1
#         self.end = 2
#         self.rows = 10
#         self.get_overview()

#     #  데이터 요약 
#     def get_overview(self):
#         print(self.url)


#     def get_request_url(self):
        
#         srch_txt = input("검색어 입력 : ")
        
#         encText = urllib.parse.quote(srch_txt)
#         self.url = f"https://openapi.naver.com/v1/search/{self.node}.json?query=" + encText 
#         self.url += f"&start={self.start}"
#         self.url += f"&display={self.rows}"
#         self.url += "&sort=sim"

#         request = urllib.request.Request(self.url)
#         request.add_header("X-Naver-Client-Id", self.client_id)
#         request.add_header("X-Naver-Client-Secret", self.client_secret)
#         response = urllib.request.urlopen(request)
#         rescode = response.getcode()


#         if(rescode==200):
            
#             result = response.read().decode('utf-8')
#             result = json.loads(result)


#             # print(type(response))
#             print(result)
#             # print(type(result))
        
#             # print("보도자료수 : ", result['total'])
#             # print(result)

        
#         else:
#             print("Error Code:" + rescode)

    
#     def get_json(self):
#         pass

    
#     def dump_json():
#         # count = 0
#         # for post 
#         pass


# if __name__ == "__main__":
#     naverAPI('news')
