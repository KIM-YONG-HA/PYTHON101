# %%
import numpy as np
import pandas as pd

# %%
wt = pd.read_csv('weather.csv')
wt
# Out:
#        w_idx islandName  baseDate  baseTime  fcstDate  fcstTime  POP  PTY  \
# 0          1   신안 반월박지도  20240821      1400  20240821      1500    0  0.0
# 1          2     고흥 연홍도  20240821      1400  20240821      1500    0  0.0
# 2          3     강진 가우도  20240821      1400  20240821      1500    0  0.0
# 3          4      여수 낭도  20240821      1400  20240821      1500    0  0.0
# 4          5     진도 금호도  20240821      1400  20240821      1500    0  0.0
# ...      ...        ...       ...       ...       ...       ...  ...  ...
# 25358  25359     완도 금당도  20250105      2300  20250106         0   30  0.0
# 25359  25360     완도 여서도  20250105      2300  20250106         0   30  0.0
# 25360  25361     영광 안마도  20250105      2300  20250106         0   20  0.0
# 25361  25362     신안 우이도  20250105      2300  20250106         0   20  0.0
# 25362  25363     여수 손죽도  20250105      2300  20250106         0   30  0.0
#
#         PCP REH  ... SKY   TMP  TMN  TMX  UUU  VVV  WAV  VEC  WSD  \
# ...
