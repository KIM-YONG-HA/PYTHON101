# %%
import pandas as pd
train_df = pd.read_csv('data/train_dataset.csv', encoding='utf-8')
test_df = pd.read_csv('data/test_dataset.csv', encoding='utf-8')

# %%
import re

def clean_text(text):
    text = re.sub(r"[^가-힣a-zA-Z0-9\s]", "", text)  # 한글, 영어, 숫자, 공백만 유지
    text = re.sub(r"\s+", " ", text).strip()  # 중복 공백 제거
    return text

train_df["text"] = train_df["text"].apply(clean_text)
test_df["text"] = test_df["text"].apply(clean_text)

# %%
from konlpy.tag import Okt
import random
import gensim
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# 🔹 Step 1: 형태소 분석기 초기화
print("🔄 형태소 분석기 (Okt) 초기화 중...")
okt = Okt()

# 🔹 Step 2: FastText 모델 로드
print("⏳ FastText 모델 로딩 중...")
fasttext_model = gensim.models.KeyedVectors.load_word2vec_format(
    "C:/fasttext/cc.ko.300.vec.gz",
    binary=False,
    encoding="utf-8"  # ✅ 인코딩을 UTF-8에서 latin1로 변경
)
print("✅ FastText 모델 로드 완료!")


# ✅ 동의어 추출 함수 (FastText 활용)
def get_synonyms(word, topn=3):
    try:
        synonyms = fasttext_model.most_similar(word, topn=topn)
        return [syn[0] for syn in synonyms]
    except KeyError:
        return [word]  # 없는 단어는 원본 유지

# ✅ Synonym Replacement (Okt 활용)
def synonym_replacement(sentence, n=1):
    words = okt.morphs(sentence)  # 형태소 분석
    new_sentence = sentence
    count = 0
    for word in words:
        synonyms = get_synonyms(word)
        if len(synonyms) > 1:
            new_sentence = new_sentence.replace(word, random.choice(synonyms), 1)
            count += 1
        if count >= n:
            break
    return new_sentence

# 🔹 Step 3: 데이터 로드
# print("📂 학습 데이터 로딩 중...")
# file_path = "train_dataset.csv"  # 실제 파일 경로로 변경
# train_df = pd.read_csv(file_path)
print(f"✅ 학습 데이터 로드 완료! 총 {len(train_df)} 개 샘플")


# 🔹 Step 4: 감정 데이터 불균형 확인
print("📊 감정 데이터 불균형 분석 중...")
emotion_counts = train_df['emotion'].value_counts()
mean_count = emotion_counts.mean()
underrepresented_emotions = emotion_counts[emotion_counts < mean_count]

print(f"🔍 부족한 감정 클래스 개수: {len(underrepresented_emotions)}")
print(underrepresented_emotions)

# 🔹 Step 5: 부족한 감정 데이터 필터링 후 증강 적용
print("🛠 부족한 감정 데이터 증강 중...")
underrepresented_df = train_df[train_df['emotion'].isin(underrepresented_emotions.index)]

augmented_texts = []
augmented_labels = []
augmented_situations = []

for _, row in tqdm(underrepresented_df.iterrows(), total=len(underrepresented_df), desc="📌 Synonym Replacement 진행 중"):
    new_text = synonym_replacement(row['text'], n=2)  # 최대 2개 단어 치환
    augmented_texts.append(new_text)
    augmented_labels.append(row['emotion'])
    augmented_situations.append(row['situation'])

print("✅ 데이터 증강 완료!")


# 🔹 Step 6: 증강된 데이터프레임 생성
augmented_df = pd.DataFrame({'text': augmented_texts, 'emotion': augmented_labels, 'situation': augmented_situations})

# 🔹 Step 7: 원본 데이터와 병합하여 최종 데이터셋 생성
print("🔗 원본 데이터와 증강 데이터를 병합 중...")
final_df = pd.concat([train_df, augmented_df])
print(f"✅ 최종 데이터셋 생성 완료! 총 {len(final_df)} 개 샘플")


# 🔹 Step 8: 시각화 - 감정 데이터 분포 비교
print("📊 데이터 증강 전후 분포 시각화...")
plt.figure(figsize=(12, 6))
plt.bar(emotion_counts.index, emotion_counts.values, label="Original", alpha=0.6)
plt.bar(final_df['emotion'].value_counts().index, final_df['emotion'].value_counts().values, label="Augmented", alpha=0.6)
plt.xlabel('Emotion Label')
plt.ylabel('Count')
plt.title('Emotion Data Distribution Before & After Augmentation')
plt.xticks(rotation=90)
plt.legend()
plt.show()

print("🎉 모든 작업 완료!")
# Out:
# 🔄 형태소 분석기 (Okt) 초기화 중...
# ⏳ FastText 모델 로딩 중...

# %%
final_df.to_csv('data/250314_augmented_train_df.csv', encoding='utf-8-sig')

# %%
tmp_df = pd.read_csv('data/250314_augmented_train_df.csv')

# %%
tmp_df = pd.read_csv('data/250314_augmented_train_df.csv', encoding='utf-8-sig')  # 또는 'latin1'

# %%
tmp_df.head(50)
# Out:
#     Unnamed: 0                                               text emotion  \
# 0            0  일은 왜 해도 해도 끝이 없을까? 화가 난다. 그냥 내가 해결하는 게 나아. 남들한...     E18
# 1            1  이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나....     E18
# 2            2  회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...     E18
# 3            3  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...     E18
# 4            4  얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나. 상사인 나에게 ...     E18
# 5            5  직장에 다니고 있지만 시간만 버리는 거 같아. 진지하게 진로에 대한 고민이 생겨. ...     E18
# 6            6  성인인데도 진로를 아직도 못 정했다고 부모님이 노여워하셔. 나도 섭섭해. 부모님께 ...     E18
# 7            7  퇴사한 지 얼마 안 됐지만 천천히 직장을 구해보려고. 더 좋은 회사가 기다리고 있을...     E66
# 8            8  졸업반이라서 취업을 생각해야 하는데 지금 너무 느긋해서 이래도 되나 싶어. 응. 느...     E37
# 9            9  요즘 직장생활이 너무 편하고 좋은 것 같아! 우리 회사는 복지가 정말 좋아! 내가 ...     E66
# 10          10  취업해야 할 나이인데 취업하고 싶지가 않아. 아직 조금 더 놀고 싶은 마음이 커. ...     E66
# 11          11  면접에서 부모님 직업에 대한 질문이 들어왔어. 무척 당혹스러웠어. 부모님 직업이 면...     E35
# 12          12  큰일이야. 부장님께 결재받아야 하는 서류가 사라졌어. 한 시간 뒤에 제출해야 하는데...     E35
# 13          13  나 얼마 전에 면접 본 회사에서 면접 합격했다고 연락받았었는데 오늘 다시 입사 취소...     E35
# 14          14  길을 가다가 우연히 마주친 동네 아주머니께서 취업했냐고 물어보셔서 당황했어. 평소 ...     E50
# 15          15  어제 합격 통보를 받은 회사에서 문자를 잘못 발송했다고 연락이 왔어. 너무 당혹스럽...     E50
# 16          16  나 오늘 첫 출근 했는데 너무 당황스러웠어! 버스 타고 카드를 찍으려고 하는데 지갑...     E50
# 17          17  이번에 직장을 이직했는데 글쎄 만나고 싶지 않은 사람을 만나서 아주 당황스럽더라고....     E50
# 18          18  코로나 때문에 뭘 할 수가 없어. 취직 준비를 해야 하는데 시험이 줄줄이 취소되니 ...     E25
# 19          19  오늘 회사에서 큰 실수를 한 것 같아. 중요한 발표가 있었는데 많은 사람 앞에서 말...     E25
# 20          20  요즘 취업 관련해서 떠올리기만 해도 온몸이 마비될 것 같아. 현재 취업 준비생인데 ...     E25
# 21          21  어제도 야근 오늘도 야근이야. 너무 힘들어. 솔직히 말하자면 굳이 야근할 일이 아니...     E25
# 22          22  우리 회사는 정말 사내 분위기가 좋아. 즐거운 일이 매일 생길 거 같은 기분이야. ...     E64
# 23          23  오늘 내가 다니는 회사가 참 좋은 직장이라는 생각이 들었어. 회사에서 내가 제안한 ...     E64
# 24          24  회사에서 전공시험을 봤어. 오늘 시험 결과가 나왔어. 열심히 준비한 만큼 원하던 점...     E64
# 25          25  면접관에게 완전히 속았어. 면접일에 알려준 연봉과 실수령액이 꽤 차이가 나네. 회사...     E42
# 26          26  지인이 취업시켜준다면서 사기를 쳤어. 배신감이 들어. 취업시켜준다면서 십만 원을 달...     E42
# 27          27  우리 부모님은 나를 버린 거나 다름없어. 내가 진로에 대해 걱정을 할 때 나를 걱정...     E49
# 28          28  계속 취업이 안 되니까 버려진 기분이야. 내가 능력이 없어서 취업이 안 되나 봐. ...     E49
# 29          29  이번에 중소기업에 취업하게 되었어. 친구들에게 말하기가 조금 부끄러워. 요즘같이 어...     E56
# 30          30  저번 주에 친구와 같은 회사에서 같이 면접을 봤는데 나만 떨어져서 너무 창피해. 친...     E56
# 31          31  요즘 청년 실업률이 너무 심각한 거 같아. 취업해야 하는데 기업들이 채용을 많이 하...     E10
# 32          32  직장에서 부당한 일을 겪어서 너무 화가 나. 이미 주변 사람에게 말해봤는데 반응은 ...     E10
# 33          33  오늘 엄마랑 진로 문제로 크게 싸웠어. 그래서 너무 화가 나. 나는 미술 쪽으로 가...     E10
# 34          34  오늘 면접은 너무 망했어! 낙하산이 있었던 것 같아. 모두 그 사람한테만 말을 걸고...     E10
# 35          35  부모님이 자꾸 취업하라고 잔소리해. 나도 아는데 자꾸 잔소리하니까 화가 나. 나도 ...     E10
# 36          36  이제 주변 친구들은 하나둘씩 다 취업에 성공하는데 아직 나만 못해서 불안해. 이러다...     E30
# 37          37  나는 내 꿈이 무엇인지 몰라서 불안해. 꿈은 모르겠지만 컴퓨터로 무언가를 작업할 때...     E30
# 38          38            코로나 때문에 출근하는 것이 불안해. 사장님께 재택근무를 요청해야겠어.     E30
# 39          39  내년이 졸업인데 취업 문제 때문에 걱정이야. 학점은 그다지 나쁘지는 않은데 워낙 실...     E30
# 40          40  직장 생활 육 개월 차인데 아직도 적응하기가 힘들어. 사회생활이 이렇게 괴롭고 슬픈...     E22
# 41          41  이번 면접에 또 떨어져서 비통한 마음이야. 아니 지나간 건 잊어버릴래. 아직 두 번...     E22
# 42          42  나 너무 우울해. 회사에서 큰 실수를 했어. 해야 하는 일이 있었는데 잊고 있다가 ...     E40
# 43          43  요즘 직장에서 너무 성가신 일이 많아서 스트레스를 많이 받고 있어. 새로 들어온 신...     E19
# 44          44  내 업무가 아닌 일을 자꾸 사수가 시키네. 정말 성가셔. 꾹 참고하는 데 이젠 한계...     E19
# 45          45  회사 동료가 자꾸 나한테 뭔가를 물어봐. 물어보는 동안은 내 업무에 집중을 못 하게...     E19
# 46          46  일이 참 귀찮게 됐어. 낙하산으로 들어온 신입사원이 우리 팀으로 배정받았어. 얘는 ...     E19
# 47          47          왜 일은 나만 많을까? 회사에서 다른 사람이 못한 일을 자꾸 나에게 넘겨.     E19
# 48          48  우리 신입은 오늘도 그냥 넘어가는 법이 없어. 일을 말끔하게 끝내질 못해서 항상 실...     E19
# 49          49  실습생 하나 담당하게 되었는데 기간이 꽤 길어서 신경 쓰이고 성가시네. 아무래도 실...     E19
#
#    situation
# 0        S06
# 1        S06
# 2        S06
# 3        S06
# 4        S06
# 5        S06
# 6        S06
# 7        S06
# 8        S06
# 9        S06
# 10       S06
# 11       S06
# 12       S06
# 13       S06
# 14       S06
# 15       S06
# 16       S06
# 17       S06
# 18       S06
# 19       S06
# 20       S06
# 21       S06
# 22       S06
# 23       S06
# 24       S06
# 25       S06
# 26       S06
# 27       S06
# 28       S06
# 29       S06
# 30       S06
# 31       S06
# 32       S06
# 33       S06
# 34       S06
# 35       S06
# 36       S06
# 37       S06
# 38       S06
# 39       S06
# 40       S06
# 41       S06
# 42       S06
# 43       S06
# 44       S06
# 45       S06
# 46       S06
# 47       S06
# 48       S06
# 49       S06
