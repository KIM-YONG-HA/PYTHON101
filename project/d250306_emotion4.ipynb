# %%
'''
04_HS01~03 합치기, 중요 키워드 줄이기 
'''
# Out:
# '\n04_HS01~03 합치기, 중요 키워드 줄이기 \n'

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **1. 학습 데이터 데이터프레임으로 변경**

# %%
file_path = 'data/감성대화말뭉치(최종데이터)_Training.json'

# JSON 파일 로드
with open(file_path, "r", encoding="utf-8") as file:
    data = json.load(file)

# DataFrame 변환
df = pd.DataFrame(data)

# 상담 텍스트(HS01, HS02, HS03만 합침) 추출
df["text"] = df["talk"].apply(lambda x: " ".join([x["content"].get(k, "") for k in ["HS01", "HS02", "HS03"]]).strip())

# 감정(E10~E69), 상황(S01~S13), 질병(D01~D02) 레이블 추출
df["emotion"] = df["profile"].apply(lambda x: x["emotion"]["type"])  # 감정 ID (E10~E69)
df["situation"] = df["profile"].apply(lambda x: ",".join(x["emotion"]["situation"]))  # 상황 ID (S01~S13)
df["disease"] = df["profile"].apply(lambda x: x["emotion"]["situation"][1] if len(x["emotion"]["situation"]) > 1 else "D02")  # 질병 ID (D01 or D02)

# 필요 없는 컬럼 제거
df = df[["text", "emotion", "situation", "disease"]]

# CSV 저장
df.to_csv("data/dataset.csv", index=False, encoding="utf-8")

# %% [markdown]
# ## **2. 데이터프레임 샘플 출력**

# %%
df.sample(50)
# Out:
#                                                     text emotion situation  \
# 46720  난 나이가 들었는데 노후 준비를 해놓은 게 거의 없어. 내가 왜 이렇게 되었는지 모...     E37   S13,D02
# 44513  축제 때 무대에 나가 춤을 추고 싶었어. 근데 다리를 다치게 돼서 나갈 수 없게 되...     E50   S04,D02
# 409    그동안의 힘든 날들에도 언제나 집안일과 가정의 경제를 책임져 준 아내에게 고마워. ...     E62   S13,D02
# 9025   요즘 부모님과 많이 부딪혀. 난 하고 싶은 일이 있는데 부모님은 안정적인 일만 하라...     E11   S06,D02
# 22490  아기가 태어난 걸 축하해주신 모든 분께 감사 인사를 드리고 싶어. 잊지 않고 축하인...     E61   S05,D02
# 38052  하고 싶은 일이 있는데 몸과 마음이 예전 같지 않아 괴로워. 주변에서도 나에게 기대...     E39   S13,D01
# 4894   불경기가 계속되니까 버티기가 너무 힘들어. 급여 삭감을 해야 하는데 마음이 너무 안...     E55   S10,D02
# 1535   가난한 집에서 태어난 게 죄는 아닌데 주변에서 무시를 당해서 속상해. 가난해서 학원...     E45   S02,D02
# 21975  친한 친구가 원하는 대학에 합격했어! 재수 중이라 걱정했는데 정말 잘됐어! 맞아. ...     E65   S04,D02
# 17890  나는 절약하기 위해 술 담배도 안 하시는 아빠를 보면 마음이 아파. 나는 아빠가 우...     E46   S01,D02
# 4140                   퇴직이 내일모레인데. 이제라도 해야지. 애들 볼 낯이 없어.     E55   S08,D02
# 18787  지하 납골당에 비가 와서 아내 유골이 소실되었는데 납골당에서 책임을 질 수 없다 해...     E57   S11,D01
# 48305  내 아픈 허리로 인해서 자식들이 간호하느라 힘든 것 같아 너무 미안해. 치료를 하면...     E52   S09,D02
# 39231  노년에 정말 필요한 것은 친구나 친척보다 생활을 같이하는 처가 중요하지. 그동안은 ...     E18   S04,D02
# 19540  딸이 내가 무능해서 자기가 좋은 대학에 못 들어갔다는 말을 듣고 죄책감으로 괴로워....     E55   S08,D02
# 27012  정부에서 노인 기초연금을 인상하겠다고 하네. 오랜만에 내게도 좋은 소식이야. 앞으로...     E60   S13,D02
# 34351  엄마는 나에게 간섭이 너무 심해. 작은 것도 간섭을 하니까 스트레스가 심해서 미칠 ...     E43   S01,D02
# 43537  요즘 돈벌이가 잘 안 되어 힘들어. 어머니와 아들딸 세 사람을 내가 다 먹여 살려야...     E11   S07,D02
# 1904   이직하기로 하고 사직서를 제출했는데 지금 직장에서 좋은 조건을 제시해 준다고 하니까...     E25   S06,D02
# 27141  딸이 아픈데 약을 제대로 챙겨 먹지 않아서 화를 냈어. 딸이 이번 기회로 나를 싫어...     E18   S09,D02
# 46893  세상에 믿을 사람 하나 없는 것 같아. 연락하고 싶은 사람도 없어. 믿던 친구가 배...     E42   S04,D02
# 20590  자식에게 조언을 해줬는데 옛날과 지금은 다르다며 듣지 않았어. 내 맘도 몰라주고 듣...     E12   S04,D02
# 10619  나도 모르게 자꾸 후배에게 거짓말을 하게 돼. 언젠가는 들킬 것 같아서 무서워. 후...     E31   S04,D02
# 3957   건강은 잃기 전에 지키는 거라고 했는데 지나고 보니 맞는 말이야. 응. 잃어버리고 ...     E23   S09,D02
# 49917  딸에게 어제 말을 너무 막 해서 스스로가 실망스러워. 갱년기라 그런지 기분조절이 안...     E11   S09,D02
# 21698  우리 집은 돈이 없어서 내가 원하는 꿈을 가질 수 없다는 게 우울해. 꿈을 이루어서...     E45   S02,D02
# 24656  간단히 장을 보려고 해도 자꾸 비싸서 아끼려고 해. 이러면서 사니까 자꾸 회의감이 ...     E11   S13,D02
# 7689   시어머니를 모시기가 힘들다고 얘기를 남편에게 해야 하는데 걱정이야. 요새 사업도 힘...     E38   S07,D02
# 26809  환갑도 안했으면 칠순은 해줘야지. 속상하고 화가 나네. 환갑도 안 했으니까 칠순은 ...     E11   S04,D02
# 11985  친구들이 자꾸만 나를 떠나가. 이유를 알 수 없어서 답답해. 황무지에 있는 기분이야...     E49   S04,D02
# 49472  친한 친구와 싸워서 울고 싶을 정도로 슬퍼. 학교에서 제일 친한 친구인데 이제는 말...     E24   S01,D02
# 24329  드디어 대출금을 다 갚게 되어 마음 편안하게 치료를 받을 수 있어서 기쁘네. 치료를...     E63   S13,D01
# 5702   병원에 갔더니 갑상샘 수치가 높다는군. 암일까 봐 불안해. 응. 의사의 목소리나 표...     E30   S09,D02
# 46530  번아웃이 왔나 봐. 회사가 지긋지긋하고 일도 재미가 없어. 맞아. 전에는 재미있었는...     E38   S10,D02
# 38279  오늘 운동 가면서 마스크를 모르고 안 가져가서 죄책감이 들더군. 그래서 편의점에서 ...     E51   S04,D02
# 27616  사춘기가 되니 하루 종일 비통한 기분만 들어. 사춘기를 이겨낼 방법을 가족들과 상의...     E15   S09,D02
# 46777  난 거동을 잘 못 하는 장애가 있는데 부모도 자식도 다 돌봐야 하는 상황이야. 나 ...     E28   S07,D02
# 40896  너무 힘들어 죽겠어. 이제 늙어서 내 몸이 너무 아파서 그런가 봐. 내 몸 하나 간...     E47   S11,D02
# 23788  야근을 며칠하고 있는지 모르겠어. 며칠째인지 셀 수도 없어. 너무 힘들어. 지금은 ...     E10   S10,D02
# 27705  내 유산만 탐내고 아픈 나는 안중에도 없는 자식들이 혐오스러울 지경이야. 내가 모은...     E24   S13,D02
# 22530  오늘 친구들과 이야기를 하는데 공감하지 못해서 슬펐어. 다들 회사 이야기를 하는데 ...     E27   S06,D02
# 38357  노인이 되고 보니 주의해야 할일도 늘어나더군. 어느 공공장소에 가게 될 때 주변사람...     E16   S11,D02
# 47039  부모와 자녀를 동시에 부양해야 하는 상황이라 너무 초조해. 비장애인들에게도 버거운 ...     E30   S07,D02
# 15955  딸 결혼을 반대했더니 딸이 집을 나가버렸어. 이렇게 될 줄 알았다면 조금 더 생각해...     E42   S07,D02
# 6539   일은 마무리가 되지 않았는데 칼퇴근하는 젊은 직원들 정말 이해가 안 돼. 책임감이 ...     E10   S10,D02
# 14046  친구들 중에 나만 아직까지도 취업을 못했어. 친구들을 만나면 서로 직장에서 있었던 ...     E20   S04,D02
# 23088  내 상사는 무능하고 하는 일도 없는데 부하직원들 덕분에 우리보다 더 좋은 평가를 받...     E21   S10,D02
# 45262  의사소통이 되지 않아 나를 외롭게 만드는 사람과 결혼한 나 자신이 너무 한심하고 실...     E11   S04,D02
# 9852   나 자신이 너무 한심해. 어느새 나이만 먹고 해 놓은 것도 없는 것 같고. 맞아. ...     E58   S10,D02
# 25424  내가 약을 먹을 시간을 잊고 있어도 가족들이 약을 챙겨주지 않았어. 너무 서운하고 ...     E22   S13,D01
#
#       disease
# 46720     D02
# 44513     D02
# 409       D02
# 9025      D02
# 22490     D02
# 38052     D01
# 4894      D02
# 1535      D02
# 21975     D02
# 17890     D02
# 4140      D02
# 18787     D01
# 48305     D02
# 39231     D02
# 19540     D02
# 27012     D02
# 34351     D02
# 43537     D02
# 1904      D02
# 27141     D02
# 46893     D02
# 20590     D02
# 10619     D02
# 3957      D02
# 49917     D02
# 21698     D02
# 24656     D02
# 7689      D02
# 26809     D02
# 11985     D02
# 49472     D02
# 24329     D01
# 5702      D02
# 46530     D02
# 38279     D02
# 27616     D02
# 46777     D02
# 40896     D02
# 23788     D02
# 27705     D02
# 22530     D02
# 38357     D02
# 47039     D02
# 15955     D02
# 6539      D02
# 14046     D02
# 23088     D02
# 45262     D02
# 9852      D02
# 25424     D01

# %% [markdown]
# ## **3. 데이터 전처리**

# %%
import re

# 데이터 로드
df = pd.read_csv("data/dataset.csv")

# 🔹 (1) 텍스트 정제: 특수문자 제거 및 공백 정리
def clean_text(text):
    text = re.sub(r"[^가-힣a-zA-Z0-9\s]", "", text)  # 한글, 영문, 숫자, 공백 제외 삭제
    text = re.sub(r"\s+", " ", text).strip()  # 연속된 공백 제거
    return text

df["text"] = df["text"].apply(clean_text)

# 🔹 (2) 중복된 질병 정보 정리
df["situation"] = df["situation"].apply(lambda x: ",".join(sorted(set(x.split(",")))))  # 중복 제거
df["disease"] = df["disease"].apply(lambda x: x.split(",")[0])  # 첫 번째 값만 유지

# 🔹 (3) 감정, 상황, 질병 ID를 숫자로 변환 (모델 입력을 위해)
emotion_mapping = {e: idx for idx, e in enumerate(sorted(df["emotion"].unique()))}
situation_mapping = {s: idx for idx, s in enumerate(sorted(set(",".join(df["situation"]).split(","))))}
disease_mapping = {"D01": 0, "D02": 1}  # 질병 여부를 0/1로 변환

df["emotion"] = df["emotion"].map(emotion_mapping)
df["situation"] = df["situation"].apply(lambda x: [situation_mapping[s] for s in x.split(",")])
df["disease"] = df["disease"].map(disease_mapping)

# 정리된 데이터 확인
print(df.head())

# CSV 저장
df.to_csv("data/processed_emotion_situation_disease.csv", index=False, encoding="utf-8-sig")
print("✅ 데이터 전처리 완료: processed_emotion_situation_disease.csv")
# Out:
#                                                 text  emotion situation  \
# 0  일은 왜 해도 해도 끝이 없을까 화가 난다 그냥 내가 해결하는 게 나아 남들한테 부...        8    [1, 7]
# 1  이번 달에 또 급여가 깎였어 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나 최...        8    [1, 7]
# 2  회사에 신입이 들어왔는데 말투가 거슬려 그런 애를 매일 봐야 한다고 생각하니까 스트...        8    [1, 7]
# 3  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜 일도 많은 데 정말 분하고 섭...        8    [1, 7]
# 4  얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나 상사인 나에게 먼...        8    [1, 7]
#
#    disease
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ✅ 데이터 전처리 완료: processed_emotion_situation_disease.csv

# %% [markdown]
# ##  **0. KoBERT 토큰화**

# %%
#!pip install torch torchvision torchaudio
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\kj\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\users\kj\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: torchaudio in c:\users\kj\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: filelock in c:\users\kj\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\kj\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\kj\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\kj\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\kj\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\kj\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kj\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kj\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\kj\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\kj\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kj\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
# !pip install transformers sentencepiece
# Out:
# Requirement already satisfied: transformers in c:\users\kj\anaconda3\lib\site-packages (4.49.0)
# Requirement already satisfied: sentencepiece in c:\users\kj\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: filelock in c:\users\kj\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (0.29.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\kj\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kj\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kj\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kj\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\kj\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kj\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kj\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kj\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kj\anaconda3\lib\site-packages (from requests->transformers) (2024.8.30)

# %%
# !pip install git+https://github.com/SKTBrain/KoBERT.git@master
# Out:
# Collecting git+https://github.com/SKTBrain/KoBERT.git@master
#   Cloning https://github.com/SKTBrain/KoBERT.git (to revision master) to c:\users\kj\appdata\local\temp\pip-req-build-0oyxamwk
#   Resolved https://github.com/SKTBrain/KoBERT.git to commit 5c46b1c68e4755b54879431bd302db621f4d2f47
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting boto3<=1.15.18 (from kobert==0.2.3)
#   Using cached boto3-1.15.18-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting gluonnlp<=0.10.0,>=0.6.0 (from kobert==0.2.3)
#   Using cached gluonnlp-0.10.0.tar.gz (344 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mxnet<=1.7.0.post2,>=1.4.0 (from kobert==0.2.3)
#   Using cached mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl.metadata (402 bytes)
# INFO: pip is looking at multiple versions of kobert to determine which version is compatible with other requirements. This could take a while.
#   Running command git clone --filter=blob:none --quiet https://github.com/SKTBrain/KoBERT.git 'C:\Users\kj\AppData\Local\Temp\pip-req-build-0oyxamwk'
# ERROR: Could not find a version that satisfies the requirement onnxruntime<=1.8.0,==1.8.0 (from kobert) (from versions: 1.17.0, 1.17.1, 1.17.3, 1.18.0, 1.18.1, 1.19.0, 1.19.2, 1.20.0, 1.20.1)
# ERROR: No matching distribution found for onnxruntime<=1.8.0,==1.8.0

# %%
from kobert import get_pytorch_kobert_model
print("✅ KoBERT 설치 확인 완료!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 from kobert import get_pytorch_kobert_model
#       2 print("✅ KoBERT 설치 확인 완료!")
#
# ModuleNotFoundError: No module named 'kobert'

# %%
import pandas as pd
import torch
from kobert import get_pytorch_kobert_model
from transformers import BertTokenizer
from torch.utils.data import Dataset, DataLoader

# 데이터 로드
df = pd.read_csv("data/processed_emotion_situation_disease.csv")

# KoBERT 모델 & 토크나이저 불러오기
kobert_model, vocab = get_pytorch_kobert_model()
tokenizer = BertTokenizer.from_pretrained('skt/kobert-base-v1')

# 🔹 (1) 토큰화 함수 정의
def tokenize_text(text):
    encoded = tokenizer.encode_plus(
        text,
        max_length=64,  # 최대 64토큰까지 사용
        padding="max_length",
        truncation=True,
        return_tensors="pt"  # PyTorch Tensor 형식으로 반환
    )
    return encoded["input_ids"].squeeze(), encoded["attention_mask"].squeeze()

# 🔹 (2) 데이터셋 클래스 정의
class EmotionDataset(Dataset):
    def __init__(self, dataframe):
        self.texts = dataframe["text"].tolist()
        self.emotions = dataframe["emotion"].tolist()
        self.situations = dataframe["situation"].apply(eval).tolist()  # 리스트 변환
        self.diseases = dataframe["disease"].tolist()

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        input_ids, attention_mask = tokenize_text(self.texts[idx])
        emotion_label = torch.tensor(self.emotions[idx], dtype=torch.long)
        situation_label = torch.tensor(self.situations[idx], dtype=torch.long)
        disease_label = torch.tensor(self.diseases[idx], dtype=torch.long)
        return input_ids, attention_mask, emotion_label, situation_label, disease_label

# 데이터셋 및 데이터로더 생성
train_dataset = EmotionDataset(df)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

print("✅ KoBERT 토큰화 및 데이터 준비 완료")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[172], line 3
#       1 import pandas as pd
#       2 import torch
# ----> 3 from kobert import get_pytorch_kobert_model
#       4 from transformers import BertTokenizer
#       5 from torch.utils.data import Dataset, DataLoader
#
# ModuleNotFoundError: No module named 'kobert'

# %%
import torch.nn as nn
from transformers import AdamW

class MultiLabelKoBERT(nn.Module):
    def __init__(self, bert, num_emotions=60, num_situations=13, num_diseases=2):
        super(MultiLabelKoBERT, self).__init__()
        self.bert = bert
        self.dropout = nn.Dropout(0.1)

        # 감정, 상황, 질병 각각의 분류기
        self.fc_emotion = nn.Linear(768, num_emotions)  # 감정 예측
        self.fc_situation = nn.Linear(768, num_situations)  # 상황 예측
        self.fc_disease = nn.Linear(768, num_diseases)  # 질병 여부 예측

    def forward(self, input_ids, attention_mask):
        output = self.bert(input_ids, attention_mask)[0]
        cls_token = output[:, 0, :]  # [CLS] 벡터 추출
        cls_token = self.dropout(cls_token)

        emotion_out = self.fc_emotion(cls_token)
        situation_out = self.fc_situation(cls_token)
        disease_out = self.fc_disease(cls_token)

        return emotion_out, situation_out, disease_out

# %%
#

# %%
# 모델, 손실 함수, 옵티마이저 정의
model = MultiLabelKoBERT(kobert_model)
criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=2e-5)

# 학습 루프
for epoch in range(3):
    model.train()
    total_loss = 0

    for batch in train_loader:
        input_ids, attention_mask, labels_emotion, labels_situation, labels_disease = batch

        optimizer.zero_grad()

        # 모델 예측
        outputs_emotion, outputs_situation, outputs_disease = model(input_ids, attention_mask)

        # 손실 계산
        loss_emotion = criterion(outputs_emotion, labels_emotion)
        loss_situation = criterion(outputs_situation, labels_situation)
        loss_disease = criterion(outputs_disease, labels_disease)

        # 총 손실 계산 및 역전파
        loss = loss_emotion + loss_situation + loss_disease
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1} | Loss: {total_loss:.4f}")

print("✅ KoBERT 학습 완료")

# %% [markdown]
# ## **0. 모델 평가**

# %%
from sklearn.metrics import accuracy_score

# 모델 평가 모드
model.eval()

preds_emotion = []
preds_situation = []
preds_disease = []
true_labels_emotion = []
true_labels_situation = []
true_labels_disease = []

for batch in train_loader:
    input_ids, attention_mask, labels_emotion, labels_situation, labels_disease = batch
    with torch.no_grad():
        outputs_emotion, outputs_situation, outputs_disease = model(input_ids, attention_mask)

        preds_emotion.extend(torch.argmax(outputs_emotion, dim=1).tolist())
        preds_situation.extend(torch.argmax(outputs_situation, dim=1).tolist())
        preds_disease.extend(torch.argmax(outputs_disease, dim=1).tolist())

        true_labels_emotion.extend(labels_emotion.tolist())
        true_labels_situation.extend(labels_situation.tolist())
        true_labels_disease.extend(labels_disease.tolist())

# 정확도 계산
accuracy_emotion = accuracy_score(true_labels_emotion, preds_emotion)
accuracy_situation = accuracy_score(true_labels_situation, preds_situation)
accuracy_disease = accuracy_score(true_labels_disease, preds_disease)

print(f"감정 분석 정확도: {accuracy_emotion:.4f}")
print(f"상황 분석 정확도: {accuracy_situation:.4f}")
print(f"질병 예측 정확도: {accuracy_disease:.4f}")
